# %%
import pandas as pd
import numpy as np
import os
import post_process as pp

exp = pp.get_data()
data = pd.read_csv('data/'+exp[1])
pp.show_fig(data)

# %%
child1 = data[data['cond'] == 'goodPhappyE']
pp.show_fig(child1)

# %%
child2 = data[data['cond'] == 'goodPsadE']
pp.show_fig(child2)

# %%
child3 = data[data['cond'] == 'badPhappyE']
pp.show_fig(child3)

# %%
child4 = data[data['cond'] == 'badPsadE']
pp.show_fig(child4)

# %%
import random
data = ['a','b','c','d','e','f','g']
# data.remove(random.choice(data))
data.pop(data.index(random.choice(data)))
data
# Out:
# ['a', 'b', 'd', 'e', 'f', 'g']
